# %%
import numpy as np
import matplotlib as mpl 
import matplotlib.pyplot as plt
import scipy
import sklearn.neighbors
import time

from data_utils import load_dataset

# %%
def knn_classification(x_train, y_train, x_test, k, l=2):
    y_star = np.empty((x_test.shape[0], 1))
    if (l==1):
        tree = sklearn.neighbors.KDTree(x_train, metric='cityblock')
    elif (l==2):
        tree = sklearn.neighbors.KDTree(x_train, metric='euclidean')
    else:
        pass
    k_nearest_neighbours = tree.query(x_test, k=k, return_distance=False, sort_results=False)
    #print(k_nearest_neighbours)
    for i, x_test_i in enumerate(x_test):
        vals, counts = np.unique(y_train[k_nearest_neighbours[i]], return_counts=True)
        #print(vals)
        #print(counts)
        if np.sum(counts==np.max(counts)) != 1:
            #print(k_nearest_neighbours[0])
            #print(y_train[k_nearest_neighbours[0]])
            y_star[i, 0] = y_train[k_nearest_neighbours[0,0]]   # pick closest neighbour if tie
        else:
            y_star[i, 0] = vals[np.argmax(counts)]
    #print(y_star)
    return y_star

# %%
np.random.seed(1000)

x_train, x_valid, x_test, y_train, y_valid, y_test = load_dataset('iris')

# convert onehot encoding to integer class
# np.tile, np.arange faster than np.argmax method
y_train = np.tile(np.arange(y_train.shape[1]).reshape((1,-1)), (y_train.shape[0], 1))[y_train].reshape((-1, 1))
y_valid = np.tile(np.arange(y_valid.shape[1]).reshape((1,-1)), (y_valid.shape[0], 1))[y_valid].reshape((-1, 1))
y_test = np.tile(np.arange(y_test.shape[1]).reshape((1,-1)), (y_test.shape[0], 1))[y_test].reshape((-1, 1))

n = int(x_train.shape[0])
t0 = time.time()
accuracy = np.empty((int(np.sqrt(n)), 2))
for a in range(1, int(np.sqrt(n))+1, 1):
    for b in range(1, 3, 1):
        y_star = knn_classification(x_train, y_train, x_valid, a, b)
        accuracy[a-1, b-1] = np.mean(y_star == y_valid)
        print("k={a}, l={b}, accuracy={accuracy}".format(a=a, b=b, accuracy=round(accuracy[a-1, b-1], 6)))

best = np.unravel_index(np.argmax(accuracy), accuracy.shape)
print("best params at k={a}, l={b} with accuracy={accuracy}".format(a=best[0]+1, b=best[1]+1, accuracy=round(accuracy[best], 6)))
print("took {t}s".format(t=round(time.time()-t0, 2)))
y_star = knn_classification(x_train, y_train, x_test, best[0]+1, best[1]+1)
print('test a ccuracy with best model: {accuracy}'.format(accuracy=round(np.mean(y_star == y_test), 6)))
# Out:
# k=1, l=1, accuracy=0.774194
# k=1, l=2, accuracy=0.774194
# k=2, l=1, accuracy=0.806452
# k=2, l=2, accuracy=0.806452
# k=3, l=1, accuracy=0.774194
# k=3, l=2, accuracy=0.806452
# k=4, l=1, accuracy=0.806452
# k=4, l=2, accuracy=0.806452
# k=5, l=1, accuracy=0.806452
# k=5, l=2, accuracy=0.83871
# k=6, l=1, accuracy=0.774194
# k=6, l=2, accuracy=0.806452
# k=7, l=1, accuracy=0.806452
# k=7, l=2, accuracy=0.870968
# k=8, l=1, accuracy=0.806452
# k=8, l=2, accuracy=0.83871
# k=9, l=1, accuracy=0.83871
# k=9, l=2, accuracy=0.870968
# k=10, l=1, accuracy=0.83871
# k=10, l=2, accuracy=0.870968
# best params at k=7, l=2 with accuracy=0.870968
# took 0.02s
# test a ccuracy with best model: 1.0

# %%
np.random.seed(1000)

x_train, x_valid, x_test, y_train, y_valid, y_test = load_dataset('mnist_small')

# convert onehot encoding to integer class
# np.tile, np.arange faster than np.argmax method
y_train = np.tile(np.arange(y_train.shape[1]).reshape((1,-1)), (y_train.shape[0], 1))[y_train].reshape((-1, 1))
y_valid = np.tile(np.arange(y_valid.shape[1]).reshape((1,-1)), (y_valid.shape[0], 1))[y_valid].reshape((-1, 1))
y_test = np.tile(np.arange(y_test.shape[1]).reshape((1,-1)), (y_test.shape[0], 1))[y_test].reshape((-1, 1))

print('dataset mnist_small')
n = int(x_train.shape[0])
print(n)
t0 = time.time()
accuracy = np.empty((int(np.sqrt(n)), 2))
for a in range(1, int(np.sqrt(n))+1, 1):
    for b in range(1, 3, 1):
        t1 = time.time()
        predictions = knn_classification(x_train, y_train, x_valid, a, b)
        print("took {t}s".format(t=round(time.time()-t1, 2)))
        accuracy[a-1, b-1] = np.mean(predictions == y_valid)
        print("took {t}s".format(t=round(time.time()-t1, 2)))
        print("k={a}, l={b}, accuracy={accuracy}".format(a=a, b=b, accuracy=round(accuracy[a-1, b-1], 6)))
best = np.unravel_index(np.argmax(accuracy), accuracy.shape)
print("best params at k={a}, l={b} with accuracy={accuracy}".format(a=best[0]+1, b=best[1]+1, accuracy=round(accuracy[best], 6)))
print("took {t}s".format(t=round(time.time()-t0, 2)))
y_star = knn_classification(x_train, y_train, x_test, best[0]+1, best[1]+1)
print('test accuracy with best model: {accuracy}'.format(accuracy=round(np.mean(y_star == y_test), 6)))
# Out:
# dataset mnist_small
# 10000
# took 5.62s
# took 5.62s
# k=1, l=1, accuracy=0.941
# took 5.73s
# took 5.73s
# k=1, l=2, accuracy=0.95
# took 5.6s
# took 5.6s
# k=2, l=1, accuracy=0.904
# took 5.73s
# took 5.73s
# k=2, l=2, accuracy=0.918
# took 5.58s
# took 5.58s
# k=3, l=1, accuracy=0.934
# took 5.78s
# took 5.78s
# k=3, l=2, accuracy=0.943
# took 5.67s
# took 5.67s
# k=4, l=1, accuracy=0.922
# took 5.89s
# took 5.89s
# k=4, l=2, accuracy=0.933
# took 5.8s
# took 5.8s
# k=5, l=1, accuracy=0.927
# took 5.85s
# took 5.85s
# k=5, l=2, accuracy=0.939
# took 5.8s
# took 5.8s
# k=6, l=1, accuracy=0.927
# took 5.79s
# took 5.79s
# k=6, l=2, accuracy=0.934
# took 5.72s
# took 5.72s
# k=7, l=1, accuracy=0.932
# took 5.87s
# took 5.87s
# k=7, l=2, accuracy=0.943
# took 5.66s
# took 5.66s
# k=8, l=1, accuracy=0.925
# took 5.74s
# took 5.74s
# k=8, l=2, accuracy=0.935
# took 5.71s
# took 5.71s
# k=9, l=1, accuracy=0.933
# took 5.81s
# took 5.81s
# k=9, l=2, accuracy=0.939
# took 5.6s
# took 5.6s
# k=10, l=1, accuracy=0.927
# took 5.73s
# took 5.73s
# k=10, l=2, accuracy=0.934
# took 5.62s
# took 5.62s
# k=11, l=1, accuracy=0.922
# took 5.73s
# took 5.73s
# k=11, l=2, accuracy=0.934
# took 5.62s
# took 5.62s
# k=12, l=1, accuracy=0.921
# took 5.74s
# took 5.74s
# k=12, l=2, accuracy=0.934
# took 5.58s
# took 5.58s
# k=13, l=1, accuracy=0.92
# took 5.75s
# took 5.75s
# k=13, l=2, accuracy=0.936
# took 5.6s
# took 5.6s
# k=14, l=1, accuracy=0.923
# took 5.95s
# took 5.95s
# k=14, l=2, accuracy=0.933
# took 5.75s
# took 5.75s
# k=15, l=1, accuracy=0.92
# took 5.73s
# took 5.73s
# k=15, l=2, accuracy=0.931
# took 5.59s
# took 5.59s
# k=16, l=1, accuracy=0.914
# took 5.94s
# took 5.94s
# k=16, l=2, accuracy=0.929
# took 5.6s
# took 5.6s
# k=17, l=1, accuracy=0.918
# took 5.75s
# took 5.75s
# k=17, l=2, accuracy=0.926
# took 5.6s
# took 5.6s
# k=18, l=1, accuracy=0.91
# took 5.77s
# took 5.77s
# k=18, l=2, accuracy=0.926
# took 5.6s
# took 5.6s
# k=19, l=1, accuracy=0.911
# took 5.73s
# took 5.73s
# k=19, l=2, accuracy=0.924
# took 5.62s
# took 5.62s
# k=20, l=1, accuracy=0.908
# took 5.73s
# took 5.73s
# k=20, l=2, accuracy=0.924
# took 5.59s
# took 5.59s
# k=21, l=1, accuracy=0.908
# took 5.76s
# took 5.76s
# k=21, l=2, accuracy=0.924
# took 5.6s
# took 5.6s
# k=22, l=1, accuracy=0.906
# took 5.82s
# took 5.82s
# k=22, l=2, accuracy=0.921
# took 5.74s
# took 5.74s
# k=23, l=1, accuracy=0.903
# took 5.95s
# took 5.95s
# k=23, l=2, accuracy=0.919
# took 5.9s
# took 5.9s
# k=24, l=1, accuracy=0.904
# took 5.94s
# took 5.94s
# k=24, l=2, accuracy=0.919
# took 5.66s
# took 5.66s
# k=25, l=1, accuracy=0.901
# took 5.87s
# took 5.87s
# k=25, l=2, accuracy=0.916
# took 5.83s
# took 5.83s
# k=26, l=1, accuracy=0.9
# took 5.97s
# took 5.97s
# k=26, l=2, accuracy=0.916
# took 5.74s
# took 5.74s
# k=27, l=1, accuracy=0.9
# took 5.89s
# took 5.89s
# k=27, l=2, accuracy=0.917
# took 5.76s
# took 5.76s
# k=28, l=1, accuracy=0.901
# took 5.93s
# took 5.93s
# k=28, l=2, accuracy=0.91
# took 5.77s
# took 5.77s
# k=29, l=1, accuracy=0.903
# took 5.87s
# took 5.87s
# k=29, l=2, accuracy=0.914
# took 5.79s
# took 5.79s
# k=30, l=1, accuracy=0.903
# took 5.9s
# took 5.9s
# k=30, l=2, accuracy=0.912
# took 5.75s
# took 5.75s
# k=31, l=1, accuracy=0.906
# took 5.85s
# took 5.85s
# k=31, l=2, accuracy=0.916
# took 5.88s
# took 5.88s
# k=32, l=1, accuracy=0.904
# took 5.81s
# took 5.81s
# k=32, l=2, accuracy=0.916
# took 5.68s
# took 5.68s
# k=33, l=1, accuracy=0.899
# took 5.85s
# took 5.85s
# k=33, l=2, accuracy=0.917
# took 5.88s
# took 5.88s
# k=34, l=1, accuracy=0.901
# took 6.02s
# took 6.03s
# k=34, l=2, accuracy=0.914
# took 6.05s
# took 6.05s
# k=35, l=1, accuracy=0.9
# took 5.86s
# took 5.86s
# k=35, l=2, accuracy=0.915
# took 5.89s
# took 5.89s
# k=36, l=1, accuracy=0.898
# took 5.91s
# took 5.91s
# k=36, l=2, accuracy=0.911
# took 5.7s
# took 5.7s
# k=37, l=1, accuracy=0.896
# took 5.79s
# took 5.79s
# k=37, l=2, accuracy=0.916
# took 6.02s
# took 6.02s
# k=38, l=1, accuracy=0.899
# took 6.38s
# took 6.38s
# k=38, l=2, accuracy=0.911
# took 6.3s
# took 6.3s
# k=39, l=1, accuracy=0.896
# took 6.31s
# took 6.31s
# k=39, l=2, accuracy=0.914
# took 6.3s
# took 6.3s
# k=40, l=1, accuracy=0.895
# took 6.49s
# took 6.49s
# k=40, l=2, accuracy=0.912
# took 6.07s
# took 6.07s
# k=41, l=1, accuracy=0.895
# took 6.27s
# took 6.27s
# k=41, l=2, accuracy=0.916
# took 6.06s
# took 6.06s
# k=42, l=1, accuracy=0.895
# took 6.35s
# took 6.35s
# k=42, l=2, accuracy=0.909
# took 6.04s
# took 6.04s
# k=43, l=1, accuracy=0.894
# took 6.28s
# took 6.28s
# k=43, l=2, accuracy=0.908
# took 6.08s
# took 6.08s
# k=44, l=1, accuracy=0.893
# took 6.3s
# took 6.3s
# k=44, l=2, accuracy=0.91
# took 6.11s
# took 6.11s
# k=45, l=1, accuracy=0.894
# took 6.31s
# took 6.31s
# k=45, l=2, accuracy=0.911
# took 6.03s
# took 6.03s
# k=46, l=1, accuracy=0.895
# took 6.34s
# took 6.34s
# k=46, l=2, accuracy=0.906
# took 6.14s
# took 6.14s
# k=47, l=1, accuracy=0.893
# took 6.35s
# took 6.35s
# k=47, l=2, accuracy=0.906
# took 6.03s
# took 6.03s
# k=48, l=1, accuracy=0.892
# took 6.36s
# took 6.36s
# k=48, l=2, accuracy=0.902
# took 6.07s
# took 6.07s
# k=49, l=1, accuracy=0.892
# took 6.27s
# took 6.27s
# k=49, l=2, accuracy=0.902
# took 6.13s
# took 6.13s
# k=50, l=1, accuracy=0.887
# took 6.28s
# took 6.28s
# k=50, l=2, accuracy=0.899
# took 6.06s
# took 6.06s
# k=51, l=1, accuracy=0.884
# took 6.27s
# took 6.27s
# k=51, l=2, accuracy=0.899
# took 6.32s
# took 6.32s
# k=52, l=1, accuracy=0.886
# took 6.24s
# took 6.24s
# k=52, l=2, accuracy=0.899
# took 6.15s
# took 6.15s
# k=53, l=1, accuracy=0.883
# took 6.37s
# took 6.37s
# k=53, l=2, accuracy=0.902
# took 6.19s
# took 6.19s
# k=54, l=1, accuracy=0.881
# took 6.42s
# took 6.42s
# k=54, l=2, accuracy=0.898
# took 6.33s
# took 6.33s
# k=55, l=1, accuracy=0.884
# took 6.5s
# took 6.5s
# k=55, l=2, accuracy=0.895
# took 6.18s
# took 6.18s
# k=56, l=1, accuracy=0.881
# took 6.52s
# took 6.52s
# k=56, l=2, accuracy=0.895
# took 6.17s
# took 6.17s
# k=57, l=1, accuracy=0.88
# took 6.44s
# took 6.44s
# k=57, l=2, accuracy=0.896
# took 6.19s
# took 6.19s
# k=58, l=1, accuracy=0.875
# took 6.36s
# took 6.36s
# k=58, l=2, accuracy=0.894
# took 6.2s
# took 6.2s
# k=59, l=1, accuracy=0.881
# took 6.44s
# took 6.44s
# k=59, l=2, accuracy=0.896
# took 6.17s
# took 6.17s
# k=60, l=1, accuracy=0.877
# took 6.34s
# took 6.34s
# k=60, l=2, accuracy=0.894
# took 6.13s
# took 6.13s
# k=61, l=1, accuracy=0.876
# took 6.32s
# took 6.32s
# k=61, l=2, accuracy=0.892
# took 6.17s
# took 6.17s
# k=62, l=1, accuracy=0.876
# took 6.34s
# took 6.34s
# k=62, l=2, accuracy=0.891
# took 6.13s
# took 6.13s
# k=63, l=1, accuracy=0.876
# took 6.34s
# took 6.34s
# k=63, l=2, accuracy=0.891
# took 6.13s
# took 6.13s
# k=64, l=1, accuracy=0.874
# took 6.35s
# took 6.35s
# k=64, l=2, accuracy=0.893
# took 6.19s
# took 6.19s
# k=65, l=1, accuracy=0.869
# took 6.35s
# took 6.35s
# k=65, l=2, accuracy=0.892
# took 6.1s
# took 6.1s
# k=66, l=1, accuracy=0.87
# took 6.37s
# took 6.37s
# k=66, l=2, accuracy=0.893
# took 6.15s
# took 6.15s
# k=67, l=1, accuracy=0.865
# took 6.38s
# took 6.38s
# k=67, l=2, accuracy=0.89
# took 6.21s
# took 6.21s
# k=68, l=1, accuracy=0.864
# took 6.33s
# took 6.33s
# k=68, l=2, accuracy=0.894
# took 6.15s
# took 6.15s
# k=69, l=1, accuracy=0.865
# took 6.46s
# took 6.46s
# k=69, l=2, accuracy=0.894
# took 6.21s
# took 6.21s
# k=70, l=1, accuracy=0.864
# took 6.51s
# took 6.51s
# k=70, l=2, accuracy=0.892
# took 6.22s
# took 6.22s
# k=71, l=1, accuracy=0.865
# took 6.42s
# took 6.42s
# k=71, l=2, accuracy=0.892
# took 6.0s
# took 6.0s
# k=72, l=1, accuracy=0.864
# took 6.27s
# took 6.27s
# k=72, l=2, accuracy=0.892
# took 6.07s
# took 6.07s
# k=73, l=1, accuracy=0.862
# took 6.42s
# took 6.42s
# k=73, l=2, accuracy=0.893
# took 6.18s
# took 6.18s
# k=74, l=1, accuracy=0.863
# took 6.32s
# took 6.32s
# k=74, l=2, accuracy=0.891
# took 6.19s
# took 6.19s
# k=75, l=1, accuracy=0.862
# took 6.36s
# took 6.36s
# k=75, l=2, accuracy=0.89
# took 6.12s
# took 6.12s
# k=76, l=1, accuracy=0.861
# took 6.53s
# took 6.53s
# k=76, l=2, accuracy=0.887
# took 6.27s
# took 6.27s
# k=77, l=1, accuracy=0.862
# took 6.41s
# took 6.41s
# k=77, l=2, accuracy=0.887
# took 6.23s
# took 6.23s
# k=78, l=1, accuracy=0.862
# took 6.31s
# took 6.31s
# k=78, l=2, accuracy=0.885
# took 6.1s
# took 6.1s
# k=79, l=1, accuracy=0.858
# took 6.32s
# took 6.32s
# k=79, l=2, accuracy=0.884
# took 6.16s
# took 6.16s
# k=80, l=1, accuracy=0.858
# took 6.33s
# took 6.33s
# k=80, l=2, accuracy=0.884
# took 6.19s
# took 6.19s
# k=81, l=1, accuracy=0.859
# took 6.31s
# took 6.31s
# k=81, l=2, accuracy=0.885
# took 6.19s
# took 6.19s
# k=82, l=1, accuracy=0.859
# took 6.35s
# took 6.35s
# k=82, l=2, accuracy=0.885
# took 6.18s
# took 6.18s
# k=83, l=1, accuracy=0.859
# took 6.33s
# took 6.33s
# k=83, l=2, accuracy=0.885
# took 6.11s
# took 6.11s
# k=84, l=1, accuracy=0.859
# took 6.26s
# took 6.26s
# k=84, l=2, accuracy=0.886
# took 6.13s
# took 6.13s
# k=85, l=1, accuracy=0.857
# took 6.3s
# took 6.3s
# k=85, l=2, accuracy=0.88
# took 6.12s
# took 6.12s
# k=86, l=1, accuracy=0.857
# took 6.46s
# took 6.46s
# k=86, l=2, accuracy=0.883
# took 6.41s
# took 6.41s
# k=87, l=1, accuracy=0.856
# took 6.45s
# took 6.45s
# k=87, l=2, accuracy=0.88
# took 6.12s
# took 6.12s
# k=88, l=1, accuracy=0.856
# took 6.36s
# took 6.36s
# k=88, l=2, accuracy=0.882
# took 6.11s
# took 6.11s
# k=89, l=1, accuracy=0.854
# took 6.28s
# took 6.28s
# k=89, l=2, accuracy=0.878
# took 6.04s
# took 6.04s
# k=90, l=1, accuracy=0.854
# took 6.29s
# took 6.29s
# k=90, l=2, accuracy=0.877
# took 6.19s
# took 6.19s
# k=91, l=1, accuracy=0.856
# took 6.27s
# took 6.27s
# k=91, l=2, accuracy=0.878
# took 6.16s
# took 6.16s
# k=92, l=1, accuracy=0.854
# took 6.36s
# took 6.36s
# k=92, l=2, accuracy=0.88
# took 6.11s
# took 6.11s
# k=93, l=1, accuracy=0.852
# took 6.41s
# took 6.41s
# k=93, l=2, accuracy=0.878
# took 6.15s
# took 6.15s
# k=94, l=1, accuracy=0.848
# took 6.28s
# took 6.28s
# k=94, l=2, accuracy=0.875
# took 6.12s
# took 6.12s
# k=95, l=1, accuracy=0.85
# took 6.32s
# took 6.32s
# k=95, l=2, accuracy=0.875
# took 6.08s
# took 6.08s
# k=96, l=1, accuracy=0.85
# took 6.3s
# took 6.3s
# k=96, l=2, accuracy=0.876
# took 6.09s
# took 6.09s
# k=97, l=1, accuracy=0.85
# took 6.27s
# took 6.27s
# k=97, l=2, accuracy=0.875
# took 6.22s
# took 6.22s
# k=98, l=1, accuracy=0.847
# took 6.3s
# took 6.3s
# k=98, l=2, accuracy=0.876
# took 6.21s
# took 6.21s
# k=99, l=1, accuracy=0.848
# took 6.37s
# took 6.37s
# k=99, l=2, accuracy=0.871
# took 6.07s
# took 6.07s
# k=100, l=1, accuracy=0.847
# took 6.3s
# took 6.3s
# k=100, l=2, accuracy=0.873
# best params at k=1, l=2 with accuracy=0.95
# took 1214.56s
# test accuracy with best model: 0.958
